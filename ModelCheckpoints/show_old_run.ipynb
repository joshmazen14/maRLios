# %%
import torch
import torch.nn as nn
import random
import gym
import gym_super_mario_bros
from nes_py.wrappers import JoypadSpace
from gym_super_mario_bros import SuperMarioBrosEnv
from tqdm import tqdm
import pickle 
import gym
import numpy as np
import collections 
import cv2
import matplotlib.pyplot as plt
import time
import datetime
import json
import sys
sys.path.append('../')
from toolkit.gym_env import *
from toolkit.action_utils import *
from toolkit.marlios_model import *
from toolkit.train_marlios import *
from toolkit.constants import *
import warnings

warnings.filterwarnings('ignore')
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
run_id='1682227242'
visualize(run_id=run_id, action_space=SIMPLE_MOVEMENT, n_actions=len(SIMPLE_MOVEMENT))
# total_rewards = load_item('total_rewards-1682227242.pkl')
# plot_rewards(ep_per_stat=100, total_rewards=total_rewards)
# Out:
#   1%|          | 11/1000 [02:03<3:05:24, 11.25s/it]
# (('A',), ('A',))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 run_id='1682227242'
# ----> 2 visualize(run_id=run_id, action_space=SIMPLE_MOVEMENT, n_actions=len(SIMPLE_MOVEMENT))
#       3 # total_rewards = load_item('total_rewards-1682227242.pkl')
#       4 # plot_rewards(ep_per_stat=100, total_rewards=total_rewards)
#
# File ~/Desktop/CSCI_566/maRLios/ModelCheckpoints/../toolkit/train_marlios.py:317, in visualize(run_id, action_space, n_actions, lr, exploration_min, ep_per_stat, exploration_max, mario_env, num_episodes, log_stats)
#     314 action_freq = {}
#     315 while True:
# --> 317     show_state(env, ep_num)
#     319     two_actions_index = agent.act(state)
#     320     two_actions_vector = agent.cur_action_space[0, two_actions_index[0]]
#
# File ~/Desktop/CSCI_566/maRLios/ModelCheckpoints/../toolkit/train_marlios.py:264, in show_state(env, ep, info)
#     262 plt.figure(3)
#     263 plt.clf()
# --> 264 plt.imshow(env.render(mode='rgb_array'))
#     265 plt.title("Episode: %d %s" % (ep, info))
#     266 plt.axis('off')
#
# File ~/Desktop/CSCI_566/env/lib/python3.10/site-packages/matplotlib/pyplot.py:2668, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2662 @_copy_docstring_and_deprecators(Axes.imshow)
#    2663 def imshow(
#    2664         X, cmap=None, norm=None, *, aspect=None, interpolation=None,
#    2665         alpha=None, vmin=None, vmax=None, origin=None, extent=None,
#    2666         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2667         resample=None, url=None, data=None, **kwargs):
# -> 2668     __ret = gca().imshow(
#    2669         X, cmap=cmap, norm=norm, aspect=aspect,
#    2670         interpolation=interpolation, alpha=alpha, vmin=vmin,
#    2671         vmax=vmax, origin=origin, extent=extent,
#    2672         interpolation_stage=interpolation_stage,
#    2673         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    2674         url=url, **({"data": data} if data is not None else {}),
#    2675         **kwargs)
#    2676     sci(__ret)
#    2677     return __ret
#
# File ~/Desktop/CSCI_566/env/lib/python3.10/site-packages/matplotlib/pyplot.py:2282, in gca()
#    2280 @_copy_docstring_and_deprecators(Figure.gca)
#    2281 def gca():
# -> 2282     return gcf().gca()
#
# File ~/Desktop/CSCI_566/env/lib/python3.10/site-packages/matplotlib/figure.py:1615, in FigureBase.gca(self)
#    1605 """
#    1606 Get the current Axes.
#    1607
#    (...)
#    1612 whether `.pyplot.get_fignums()` is empty.)
#    1613 """
#    1614 ax = self._axstack.current()
# -> 1615 return ax if ax is not None else self.add_subplot()
#
# File ~/Desktop/CSCI_566/env/lib/python3.10/site-packages/matplotlib/figure.py:743, in FigureBase.add_subplot(self, *args, **kwargs)
#     740         args = tuple(map(int, str(args[0])))
#     741     projection_class, pkw = self._process_projection_requirements(
#     742         *args, **kwargs)
# --> 743     ax = projection_class(self, *args, **pkw)
#     744     key = (projection_class, pkw)
#     745 return self._add_axes_internal(ax, key)
#
# File ~/Desktop/CSCI_566/env/lib/python3.10/site-packages/matplotlib/axes/_base.py:675, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, *args, **kwargs)
#     672 self.spines = mspines.Spines.from_dict(self._gen_axes_spines())
#     674 # this call may differ for non-sep axes, e.g., polar
# --> 675 self._init_axis()
#     676 if facecolor is None:
#     677     facecolor = mpl.rcParams['axes.facecolor']
#
# File ~/Desktop/CSCI_566/env/lib/python3.10/site-packages/matplotlib/axes/_base.py:821, in _AxesBase._init_axis(self)
#     818 def _init_axis(self):
#     819     # This is moved out of __init__ because non-separable axes don't use it
#     820     self.xaxis = maxis.XAxis(self)
# --> 821     self.spines.bottom.register_axis(self.xaxis)
#     822     self.spines.top.register_axis(self.xaxis)
#     823     self.yaxis = maxis.YAxis(self)
#
# File ~/Desktop/CSCI_566/env/lib/python3.10/site-packages/matplotlib/spines.py:218, in Spine.register_axis(self, axis)
#     216 self.axis = axis
#     217 if self.axis is not None:
# --> 218     self.axis.clear()
#     219 self.stale = True
#
# File ~/Desktop/CSCI_566/env/lib/python3.10/site-packages/matplotlib/axis.py:872, in Axis.clear(self)
#     869 self.offsetText._reset_visual_defaults()
#     870 self.labelpad = mpl.rcParams['axes.labelpad']
# --> 872 self._init()
#     874 self._set_scale('linear')
#     876 # Clear the callback registry for this axis, or it may "leak"
#
# File ~/Desktop/CSCI_566/env/lib/python3.10/site-packages/matplotlib/axis.py:2248, in XAxis._init(self)
#    2242 """
#    2243 Initialize the label and offsetText instance values and
#    2244 `label_position` / `offset_text_position`.
#    2245 """
#    2246 # x in axes coords, y in display coords (to be updated at draw time by
#    2247 # _update_label_positions and _update_offset_text_position).
# -> 2248 self.label.set(
#    2249     x=0.5, y=0,
#    2250     verticalalignment='top', horizontalalignment='center',
#    2251     transform=mtransforms.blended_transform_factory(
#    2252         self.axes.transAxes, mtransforms.IdentityTransform()),
#    2253 )
#    2254 self.label_position = 'bottom'
#    2256 self.offsetText.set(
#    2257     x=1, y=0,
#    2258     verticalalignment='top', horizontalalignment='right',
#    (...)
#    2262     color=mpl.rcParams['xtick.color'],
#    2263 )
#
# File ~/Desktop/CSCI_566/env/lib/python3.10/site-packages/matplotlib/artist.py:147, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     139 if not hasattr(cls.set, '_autogenerated_signature'):
#     140     # Don't overwrite cls.set if the subclass or one of its parents
#     141     # has defined a set method set itself.
#     142     # If there was no explicit definition, cls.set is inherited from
#     143     # the hierarchy of auto-generated set methods, which hold the
#     144     # flag _autogenerated_signature.
#     145     return
# --> 147 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     148 cls.set.__name__ = "set"
#     149 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File ~/Desktop/CSCI_566/env/lib/python3.10/site-packages/matplotlib/artist.py:1227, in Artist.set(self, **kwargs)
#    1217     """
#    1218     Update artist properties without prenormalizing them, but generating
#    1219     errors as if calling `set`.
#    1220
#    1221     The lack of prenormalization is to maintain backcompatibility.
#    1222     """
#    1223     return self._update_props(
#    1224         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1225         "{prop_name!r}")
# -> 1227 def set(self, **kwargs):
#    1228     # docstring and signature are auto-generated via
#    1229     # Artist._update_set_signature_and_docstring() at the end of the
#    1230     # module.
#    1231     return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#    1233 @contextlib.contextmanager
#    1234 def _cm_set(self, **kwargs):
#
# KeyboardInterrupt:
